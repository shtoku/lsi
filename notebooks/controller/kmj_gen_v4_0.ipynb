# %% [markdown]
# # PSからPLを制御するためのプログラム

# %% [markdown]
# ## import

# %%
import numpy as np
from time import sleep, time
from pynq import PL, Overlay, MMIO, allocate

# %%
N = 10
batch_size = 32

# %% [markdown]
# ## PL制御クラス

# %%
class Controller:
  def __init__(self, bitfile, batch_size, N):
    PL.reset()

    ol = Overlay(bitfile)

    dma = ol.axi_dma_0
    self.dma_send = dma.sendchannel
    self.dma_recv = dma.recvchannel

    self.top_mmio = MMIO(ol.ip_dict['top_0']['phys_addr'], ol.ip_dict['top_0']['addr_range'])
    # slv_reg0[2:0] : {next, run, rst_n}
    self.top_mmio.write(0*4, 0b0000)
    
    self.input_buffer  = allocate(shape=(batch_size, N), dtype=np.uint8)
    self.output_buffer = allocate(shape=(batch_size, N), dtype=np.uint8)
  
  def send_data(self, data):
    self.input_buffer[:] = data
    
    self.dma_send.transfer(self.input_buffer)
    while not self.dma_send.idle:
      sleep(0.001)
  
  def recv_data(self):
    self.dma_recv.transfer(self.output_buffer)
    while not self.dma_recv.idle:
      sleep(0.001)
    return self.output_buffer
  
  def run_mode(self, mode=1):
    # slv_reg1[1:0] : mode
    self.top_mmio.write(1*4, mode)

    # slv_reg0[2:0] : {next, run, rst_n}
    self.top_mmio.write(0*4, 0b101)

    # slv_reg0[2:0] : {next, run, rst_n}
    self.top_mmio.write(0*4, 0b011)

    # slv_reg2[0] : finish
    while self.top_mmio.read(2*4) != 1:
      sleep(0.001)

# %% [markdown]
# ## 関数

# %% [markdown]
# ### 文字列変換用

# %%
# 使用できる文字のリストを読み込み
char_list = []
with open('char_list_72.txt' , 'r', encoding='utf-8') as file:
  for line in file:
    char_list.append(line.replace('\n', ''))


# 文字リストの番号を顔文字中の番号を対応付け
def convert_str_int(kmj_data, N=10):
  kmj_index = []
  for kmj in kmj_data:
    kmj = list(kmj)
    kmj += ['<PAD>' for _ in range(N - len(kmj))]
    temp = []
    for c in kmj:
      try:
        temp.append(char_list.index(c))
      except:
        temp.append(char_list.index('<UNK>'))
    kmj_index.append(temp)
  
  return kmj_index


# 整数列を文字列に変換
def convert_int_str(x):
  x = np.array(char_list)[x]
  x = [c for c in x if c not in ['<PAD>', '<UNK>']]

  return ''.join(x)

# %% [markdown]
# ### ミニバッチの作成用

# %%
# データセットを読み込む関数
def read_dataset(filename):
  kmj_dataset = []
  with open(filename, 'r', encoding='utf-8') as file:
    for line in file:
      kmj_dataset.append(line.replace('\n', ''))

  return kmj_dataset


# データの前処理を行う関数
# 顔文字を文字ごとに分解 -> 番号付け -> One-hotベクトル
def preprocess(kmj_data):

  # 文字リストの番号を顔文字中の番号を対応付け
  kmj_index = []
  for kmj in kmj_data:
    kmj = list(kmj)
    kmj += ['<PAD>' for _ in range(N - len(kmj))]
    temp = []
    for c in kmj:
      try:
        temp.append(char_list.index(c))
      except:
        temp.append(char_list.index('<UNK>'))
    kmj_index.append(temp)

  # 付けた番号をOne-hotベクトル化
  kmj_num = len(kmj_index)                        # 顔文字数
  char_num = len(char_list)                       # 文字の種類数
  kmj_onehot = np.zeros((kmj_num, N, char_num))   # One-hotベクトルリスト
  for i, index in enumerate(kmj_index):
    mask = range(char_num) == np.array(index).reshape((N, 1))
    kmj_onehot[i][mask] = 1
  
  return kmj_onehot


# ミニバッチを作成する関数
def create_batch(batch_size):
  # データセットの読み込み
  kmj_dataset = read_dataset('kaomoji_MAX=10_DA.txt')

  # データの前処理
  kmj_onehot = preprocess(kmj_dataset)
  kmj_int = kmj_onehot.argmax(axis=-1)

  # データセットを分割
  train_size = int(len(kmj_dataset) * 0.85)
  valid_size = int(len(kmj_dataset) * 0.10)
  test_size  = len(kmj_dataset) - train_size - valid_size

  dataset_train = kmj_int[:train_size]
  dataset_valid = kmj_int[train_size:train_size+valid_size]
  dataset_test  = kmj_int[train_size+valid_size:]

  # ミニバッチに分割
  n_train = int(train_size / batch_size)
  n_valid = int(valid_size / batch_size)
  n_test  = int( test_size / batch_size)

  dataloader_train = [dataset_train[i*batch_size:(i+1)*batch_size] for i in range(n_train)]
  dataloader_valid = [dataset_valid[i*batch_size:(i+1)*batch_size] for i in range(n_valid)]
  dataloader_test  = [ dataset_test[i*batch_size:(i+1)*batch_size] for i in range(n_test )]

  return dataloader_train, dataloader_valid, dataloader_test

# %% [markdown]
# ## 動作検証

# %%
# ミニバッチ作成
dataloader_train, dataloader_valid, dataloader_test = create_batch(batch_size)

# %% [markdown]
# ### 学習

# %%
# PL制御クラスのインスタンス
pl = Controller('kmj_gen_v4_0.bit', batch_size, N)

# %%
n_epochs = 100
learning_time = 0

for epoch in range(n_epochs):
  acc_train = 0
  acc_valid = 0
    
  start = time()
  
  # Train
  pl.top_mmio.write(1*4, 0)    # slv_reg1[1:0] : mode (TRAIN)

  pl.send_data(dataloader_train[0])
  pl.top_mmio.write(0*4, 0b101)    # slv_reg0[2:0] : {next, run, rst_n}
  pl.top_mmio.write(0*4, 0b011)    # slv_reg0[2:0] : {next, run, rst_n}

  for i, batch in enumerate(dataloader_train[1:]):
    pl.send_data(batch)
    
    while pl.top_mmio.read(2*4) != 1: # slv_reg2[0] : finish
      sleep(0.001)

    pl.top_mmio.write(0*4, 0b101)    # slv_reg0[2:0] : {next, run, rst_n}
    pl.top_mmio.write(0*4, 0b011)    # slv_reg0[2:0] : {next, run, rst_n}
      
    recv_data = pl.recv_data()
    acc_train += (recv_data == dataloader_train[i]).sum()
  
  while pl.top_mmio.read(2*4) != 1: # slv_reg2[0] : finish
    sleep(0.001)
  
  recv_data = pl.recv_data()
  acc_train += (recv_data == dataloader_train[-1]).sum()


  # Valid
  pl.top_mmio.write(1*4, 1)    # slv_reg1[1:0] : mode (FORWARD)

  pl.send_data(dataloader_valid[0])
  pl.top_mmio.write(0*4, 0b101)    # slv_reg0[2:0] : {next, run, rst_n}
  pl.top_mmio.write(0*4, 0b011)    # slv_reg0[2:0] : {next, run, rst_n}

  for i, batch in enumerate(dataloader_valid[1:]):
    pl.send_data(batch)
    
    while pl.top_mmio.read(2*4) != 1: # slv_reg2[0] : finish
      sleep(0.001)

    pl.top_mmio.write(0*4, 0b101)    # slv_reg0[2:0] : {next, run, rst_n}
    pl.top_mmio.write(0*4, 0b011)    # slv_reg0[2:0] : {next, run, rst_n}
      
    recv_data = pl.recv_data()
    acc_valid += (recv_data == dataloader_valid[i]).sum()
  
  while pl.top_mmio.read(2*4) != 1: # slv_reg2[0] : finish
    sleep(0.001)
  
  recv_data = pl.recv_data()
  acc_valid += (recv_data == dataloader_valid[-1]).sum()

  end = time()
  learning_time += end - start

  print('EPOCH: {:>3}, Train Acc: {:>.3f}, Valid Acc: {:>.3f}, Time: {:>6.3f}'.format(
          epoch+1,
          acc_train / (len(dataloader_train) * batch_size * N),
          acc_valid / (len(dataloader_valid) * batch_size * N),
          learning_time
       ))
# Out:
# EPOCH:   1, Train Acc: 0.238, Valid Acc: 0.334, Time:  0.152
# EPOCH:   2, Train Acc: 0.343, Valid Acc: 0.363, Time:  0.303
# EPOCH:   3, Train Acc: 0.384, Valid Acc: 0.396, Time:  0.456
# EPOCH:   4, Train Acc: 0.412, Valid Acc: 0.419, Time:  0.606
# EPOCH:   5, Train Acc: 0.433, Valid Acc: 0.443, Time:  0.759
# EPOCH:   6, Train Acc: 0.454, Valid Acc: 0.459, Time:  0.910
# EPOCH:   7, Train Acc: 0.468, Valid Acc: 0.470, Time:  1.063
# EPOCH:   8, Train Acc: 0.477, Valid Acc: 0.476, Time:  1.214
# EPOCH:   9, Train Acc: 0.484, Valid Acc: 0.482, Time:  1.368
# EPOCH:  10, Train Acc: 0.490, Valid Acc: 0.490, Time:  1.519
# EPOCH:  11, Train Acc: 0.498, Valid Acc: 0.497, Time:  1.673
# EPOCH:  12, Train Acc: 0.507, Valid Acc: 0.505, Time:  1.824
# EPOCH:  13, Train Acc: 0.516, Valid Acc: 0.516, Time:  1.978
# EPOCH:  14, Train Acc: 0.527, Valid Acc: 0.524, Time:  2.129
# EPOCH:  15, Train Acc: 0.536, Valid Acc: 0.533, Time:  2.282
# EPOCH:  16, Train Acc: 0.544, Valid Acc: 0.541, Time:  2.434
# EPOCH:  17, Train Acc: 0.552, Valid Acc: 0.549, Time:  2.587
# EPOCH:  18, Train Acc: 0.559, Valid Acc: 0.557, Time:  2.738
# EPOCH:  19, Train Acc: 0.567, Valid Acc: 0.563, Time:  2.892
# EPOCH:  20, Train Acc: 0.574, Valid Acc: 0.569, Time:  3.044
# EPOCH:  21, Train Acc: 0.580, Valid Acc: 0.575, Time:  3.197
# EPOCH:  22, Train Acc: 0.586, Valid Acc: 0.583, Time:  3.349
# EPOCH:  23, Train Acc: 0.591, Valid Acc: 0.587, Time:  3.502
# EPOCH:  24, Train Acc: 0.596, Valid Acc: 0.590, Time:  3.654
# EPOCH:  25, Train Acc: 0.599, Valid Acc: 0.594, Time:  3.808
# EPOCH:  26, Train Acc: 0.603, Valid Acc: 0.598, Time:  3.959
# EPOCH:  27, Train Acc: 0.606, Valid Acc: 0.601, Time:  4.113
# EPOCH:  28, Train Acc: 0.610, Valid Acc: 0.604, Time:  4.264
# EPOCH:  29, Train Acc: 0.613, Valid Acc: 0.608, Time:  4.417
# EPOCH:  30, Train Acc: 0.616, Valid Acc: 0.612, Time:  4.569
# EPOCH:  31, Train Acc: 0.619, Valid Acc: 0.616, Time:  4.722
# EPOCH:  32, Train Acc: 0.623, Valid Acc: 0.618, Time:  4.873
# EPOCH:  33, Train Acc: 0.626, Valid Acc: 0.621, Time:  5.026
# EPOCH:  34, Train Acc: 0.630, Valid Acc: 0.624, Time:  5.177
# EPOCH:  35, Train Acc: 0.632, Valid Acc: 0.626, Time:  5.330
# EPOCH:  36, Train Acc: 0.635, Valid Acc: 0.629, Time:  5.481
# EPOCH:  37, Train Acc: 0.638, Valid Acc: 0.633, Time:  5.634
# EPOCH:  38, Train Acc: 0.640, Valid Acc: 0.637, Time:  5.786
# EPOCH:  39, Train Acc: 0.643, Valid Acc: 0.639, Time:  5.939
# EPOCH:  40, Train Acc: 0.646, Valid Acc: 0.640, Time:  6.089
# EPOCH:  41, Train Acc: 0.647, Valid Acc: 0.643, Time:  6.243
# EPOCH:  42, Train Acc: 0.649, Valid Acc: 0.645, Time:  6.395
# EPOCH:  43, Train Acc: 0.651, Valid Acc: 0.648, Time:  6.548
# EPOCH:  44, Train Acc: 0.653, Valid Acc: 0.651, Time:  6.700
# EPOCH:  45, Train Acc: 0.655, Valid Acc: 0.652, Time:  6.852
# EPOCH:  46, Train Acc: 0.658, Valid Acc: 0.653, Time:  7.004
# EPOCH:  47, Train Acc: 0.659, Valid Acc: 0.655, Time:  7.157
# EPOCH:  48, Train Acc: 0.661, Valid Acc: 0.656, Time:  7.309
# EPOCH:  49, Train Acc: 0.663, Valid Acc: 0.659, Time:  7.462
# EPOCH:  50, Train Acc: 0.664, Valid Acc: 0.660, Time:  7.614
# EPOCH:  51, Train Acc: 0.666, Valid Acc: 0.661, Time:  7.768
# EPOCH:  52, Train Acc: 0.667, Valid Acc: 0.663, Time:  7.920
# EPOCH:  53, Train Acc: 0.669, Valid Acc: 0.666, Time:  8.073
# EPOCH:  54, Train Acc: 0.670, Valid Acc: 0.667, Time:  8.226
# EPOCH:  55, Train Acc: 0.672, Valid Acc: 0.668, Time:  8.378
# EPOCH:  56, Train Acc: 0.673, Valid Acc: 0.669, Time:  8.531
# EPOCH:  57, Train Acc: 0.675, Valid Acc: 0.670, Time:  8.684
# EPOCH:  58, Train Acc: 0.677, Valid Acc: 0.671, Time:  8.836
# EPOCH:  59, Train Acc: 0.678, Valid Acc: 0.671, Time:  8.989
# EPOCH:  60, Train Acc: 0.671, Valid Acc: 0.667, Time:  9.141
# EPOCH:  61, Train Acc: 0.678, Valid Acc: 0.668, Time:  9.295
# EPOCH:  62, Train Acc: 0.679, Valid Acc: 0.671, Time:  9.447
# EPOCH:  63, Train Acc: 0.681, Valid Acc: 0.672, Time:  9.600
# EPOCH:  64, Train Acc: 0.683, Valid Acc: 0.673, Time:  9.752
# EPOCH:  65, Train Acc: 0.684, Valid Acc: 0.676, Time:  9.905
# EPOCH:  66, Train Acc: 0.685, Valid Acc: 0.678, Time: 10.057
# EPOCH:  67, Train Acc: 0.685, Valid Acc: 0.677, Time: 10.210
# EPOCH:  68, Train Acc: 0.686, Valid Acc: 0.679, Time: 10.362
# EPOCH:  69, Train Acc: 0.688, Valid Acc: 0.680, Time: 10.515
# EPOCH:  70, Train Acc: 0.676, Valid Acc: 0.673, Time: 10.666
# EPOCH:  71, Train Acc: 0.681, Valid Acc: 0.675, Time: 10.820
# EPOCH:  72, Train Acc: 0.685, Valid Acc: 0.682, Time: 10.972
# EPOCH:  73, Train Acc: 0.688, Valid Acc: 0.683, Time: 11.126
# EPOCH:  74, Train Acc: 0.689, Valid Acc: 0.685, Time: 11.278
# EPOCH:  75, Train Acc: 0.690, Valid Acc: 0.685, Time: 11.432
# EPOCH:  76, Train Acc: 0.692, Valid Acc: 0.686, Time: 11.584
# EPOCH:  77, Train Acc: 0.693, Valid Acc: 0.687, Time: 11.737
# EPOCH:  78, Train Acc: 0.694, Valid Acc: 0.688, Time: 11.888
# EPOCH:  79, Train Acc: 0.695, Valid Acc: 0.688, Time: 12.042
# EPOCH:  80, Train Acc: 0.696, Valid Acc: 0.688, Time: 12.192
# EPOCH:  81, Train Acc: 0.697, Valid Acc: 0.690, Time: 12.346
# EPOCH:  82, Train Acc: 0.698, Valid Acc: 0.691, Time: 12.496
# EPOCH:  83, Train Acc: 0.699, Valid Acc: 0.691, Time: 12.649
# EPOCH:  84, Train Acc: 0.700, Valid Acc: 0.691, Time: 12.800
# EPOCH:  85, Train Acc: 0.699, Valid Acc: 0.693, Time: 12.952
# EPOCH:  86, Train Acc: 0.699, Valid Acc: 0.685, Time: 13.103
# EPOCH:  87, Train Acc: 0.679, Valid Acc: 0.671, Time: 13.256
# EPOCH:  88, Train Acc: 0.681, Valid Acc: 0.667, Time: 13.408
# EPOCH:  89, Train Acc: 0.681, Valid Acc: 0.678, Time: 13.560
# EPOCH:  90, Train Acc: 0.687, Valid Acc: 0.684, Time: 13.712
# EPOCH:  91, Train Acc: 0.693, Valid Acc: 0.689, Time: 13.865
# EPOCH:  92, Train Acc: 0.696, Valid Acc: 0.690, Time: 14.016
# EPOCH:  93, Train Acc: 0.698, Valid Acc: 0.694, Time: 14.169
# EPOCH:  94, Train Acc: 0.676, Valid Acc: 0.691, Time: 14.320
# EPOCH:  95, Train Acc: 0.700, Valid Acc: 0.694, Time: 14.473
# EPOCH:  96, Train Acc: 0.703, Valid Acc: 0.695, Time: 14.624
# EPOCH:  97, Train Acc: 0.701, Valid Acc: 0.693, Time: 14.777
# EPOCH:  98, Train Acc: 0.702, Valid Acc: 0.686, Time: 14.928
# EPOCH:  99, Train Acc: 0.700, Valid Acc: 0.693, Time: 15.081
# EPOCH: 100, Train Acc: 0.699, Valid Acc: 0.691, Time: 15.233

# %% [markdown]
# ### 検証

# %%
pl.top_mmio.write(0*4, 0b000)    # slv_reg0[2:0] : {next, run, rst_n}

# %%
kmj = dataloader_test[0]
pl.send_data(kmj)

pl.run_mode(3)

recv_data = pl.recv_data()

# %%
for i in range(batch_size):
#   print('base     :', convert_int_str(kmj[i]))
  print('generate :', convert_int_str(recv_data[i]))
# Out:
# generate : )!(^-^　)))
# generate : (　^`　。)
# generate : (・_(・
# generate : )(・・)
# generate : *-)゚_゚　)ノ
# generate : ヾ(・`∀・　)
# generate : (゚^)^*゚^-!
# generate : (゚--)ノ)!・
# generate : )*^∀゚́*)
# generate : `)-)・*
# generate : ́(　̄)
# generate : (゚^^(゚)^・)
# generate : *^((　　・)!
# generate : )(　_・　)
# generate : (ヾ∀　*)・!
# generate : ̄　́　)ノ((
# generate : ヾ(≧^　^)
# generate : !・　;))・・!
# generate : (̄-́*)ノ!
# generate : (^-;)ノ
# generate : (　　_　　)!
# generate : ヾ(・))・_-)
# generate : )((゚∀^)ノ
# generate : (　_　^))・!
# generate : 　ヾ(・^*)
# generate : !-/-゚・^゚^ノ
# generate : ヾ(゚-)・　`))
# generate : )^　̄　))(
# generate : (　^ω`*)
# generate : ・ヾ(^_　))
# generate : (`^-)
# generate : !-ノ^゚^^-^!
